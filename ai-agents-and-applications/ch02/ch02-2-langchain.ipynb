# %%
from langchain_openai import ChatOpenAI
import getpass

# %%
OPENAI_API_KEY = getpass.getpass('Enter your OPENAI_API_KEY')
# Out:
# Enter your OPENAI_API_KEY ········

# %%
llm = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    openai_api_key=OPENAI_API_KEY,
    model_name="gpt-5-nano"
)

# %%
prompt_input = """Write a concise message to remind
users to be vigilant about phishing attacks."""

# %%
response = llm.invoke(prompt_input)

# %%
print(response.content)
# Out:
# Phishing alert: Don’t click suspicious links or share credentials. Verify the sender and report any questionable messages.
